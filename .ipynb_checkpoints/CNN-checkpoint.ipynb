# %%
# Imports
import os, warnings
import matplotlib.pyplot as plt
from matplotlib import gridspec

import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory
physical_devices = tf.config.list_physical_devices('GPU')
physical_devices
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Reproducability
def set_seed(seed=31415):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'

set_seed()

# %%
# Set Matplotlib defaults
plt.rc('figure', autolayout = True)
plt.rc('axes', labelweight = 'bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('image', cmap='magma')
warnings.filterwarnings("ignore") # to clean up output cells

# %%
# Load training and validation sets
ds_train_ = image_dataset_from_directory(
    'Kaggle_Computer_Vision/archive/train',
    labels='inferred',
    label_mode='binary',
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=True,
)
ds_valid_ = image_dataset_from_directory(
    'Kaggle_Computer_Vision/archive/valid',
    labels='inferred',
    label_mode='binary',
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=False,
)
# Out:
# Found 5117 files belonging to 2 classes.
# Found 5051 files belonging to 2 classes.

# %%
# Data Pipeline
def convert_to_float(image, label):
    image = tf.image.convert_image_dtype(image, dtype=tf.float32)
    return image, label

AUTOTUNE = tf.data.experimental.AUTOTUNE
ds_train = (
    ds_train_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
ds_valid = (
    ds_valid_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    # First Convolutional Block
    layers.Conv2D(filters = 32, kernel_size = 3, activation = 'relu', padding = 'same',
                 # give the input dimensions in the first layer
                 # [height, width, color channels (RGB)]
                  input_shape = [128,128,3]),
    layers.MaxPool2D(),

    # Second Convolutional Block
    layers.Conv2D(filters = 64, kernel_size = 3, activation = 'relu', padding = 'same'),
    layers.MaxPool2D(),    

    # Third Convolutional Block
    layers.Conv2D(filters = 128, kernel_size = 3, activation = 'relu', padding = 'same'),
    layers.MaxPool2D(),

    # Classifier head
    layers.Flatten(),
    layers.Dense(units = 6, activation = 'relu'),
    layers.Dense(units = 1, activation = 'sigmoid'),
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 6)                 196614
#
#  dense_1 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 289,869
# Trainable params: 289,869
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer = tf.keras.optimizers.Adam(epsilon = 0.01),
    loss = 'binary_crossentropy',
    metrics = ['binary_accuracy']
)

history = model.fit(
    ds_train,
    validation_data = ds_valid,
    epochs = 40,
    verbose = 1,
)
# Out:
# Epoch 1/40
# 80/80 [==============================] - 31s 148ms/step - loss: 0.6907 - binary_accuracy: 0.5662 - val_loss: 0.6832 - val_binary_accuracy: 0.5785
# Epoch 2/40
# 80/80 [==============================] - 9s 112ms/step - loss: 0.6715 - binary_accuracy: 0.5787 - val_loss: 0.6636 - val_binary_accuracy: 0.5785
# Epoch 3/40
# 80/80 [==============================] - 9s 112ms/step - loss: 0.6601 - binary_accuracy: 0.5787 - val_loss: 0.6542 - val_binary_accuracy: 0.5785
# Epoch 4/40
# 80/80 [==============================] - 9s 112ms/step - loss: 0.6513 - binary_accuracy: 0.5787 - val_loss: 0.6456 - val_binary_accuracy: 0.5785
# Epoch 5/40
# 80/80 [==============================] - 9s 113ms/step - loss: 0.6420 - binary_accuracy: 0.6013 - val_loss: 0.6417 - val_binary_accuracy: 0.6017
# Epoch 6/40
# 80/80 [==============================] - 10s 120ms/step - loss: 0.6340 - binary_accuracy: 0.6373 - val_loss: 0.6401 - val_binary_accuracy: 0.6254
# Epoch 7/40
# 80/80 [==============================] - 10s 121ms/step - loss: 0.6271 - binary_accuracy: 0.6467 - val_loss: 0.6396 - val_binary_accuracy: 0.6207
# Epoch 8/40
# 80/80 [==============================] - 10s 121ms/step - loss: 0.6127 - binary_accuracy: 0.6666 - val_loss: 0.6122 - val_binary_accuracy: 0.6585
# Epoch 9/40
# 80/80 [==============================] - 10s 122ms/step - loss: 0.5958 - binary_accuracy: 0.6859 - val_loss: 0.6053 - val_binary_accuracy: 0.6723
# Epoch 10/40
# 80/80 [==============================] - 10s 120ms/step - loss: 0.5739 - binary_accuracy: 0.7037 - val_loss: 0.5796 - val_binary_accuracy: 0.6961
# Epoch 11/40
# 80/80 [==============================] - 9s 112ms/step - loss: 0.5422 - binary_accuracy: 0.7352 - val_loss: 0.5476 - val_binary_accuracy: 0.7206
# Epoch 12/40
# 80/80 [==============================] - 10s 121ms/step - loss: 0.5114 - binary_accuracy: 0.7543 - val_loss: 0.5574 - val_binary_accuracy: 0.7121
# Epoch 13/40
# 80/80 [==============================] - 10s 124ms/step - loss: 0.4809 - binary_accuracy: 0.7831 - val_loss: 0.5262 - val_binary_accuracy: 0.7383
# Epoch 14/40
# 80/80 [==============================] - 10s 122ms/step - loss: 0.4459 - binary_accuracy: 0.8007 - val_loss: 0.4922 - val_binary_accuracy: 0.7632
# Epoch 15/40
# 80/80 [==============================] - 10s 122ms/step - loss: 0.4149 - binary_accuracy: 0.8226 - val_loss: 0.4789 - val_binary_accuracy: 0.7701
# Epoch 16/40
# 80/80 [==============================] - 10s 120ms/step - loss: 0.3833 - binary_accuracy: 0.8386 - val_loss: 0.4529 - val_binary_accuracy: 0.7921
# Epoch 17/40
# 80/80 [==============================] - 9s 117ms/step - loss: 0.3527 - binary_accuracy: 0.8562 - val_loss: 0.4407 - val_binary_accuracy: 0.7987
# Epoch 18/40
# 80/80 [==============================] - 10s 122ms/step - loss: 0.3236 - binary_accuracy: 0.8698 - val_loss: 0.4371 - val_binary_accuracy: 0.8000
# Epoch 19/40
# 80/80 [==============================] - 10s 122ms/step - loss: 0.2955 - binary_accuracy: 0.8822 - val_loss: 0.4319 - val_binary_accuracy: 0.8048
# Epoch 20/40
# 80/80 [==============================] - 10s 122ms/step - loss: 0.2609 - binary_accuracy: 0.8986 - val_loss: 0.4336 - val_binary_accuracy: 0.8074
# Epoch 21/40
# 80/80 [==============================] - 10s 122ms/step - loss: 0.2276 - binary_accuracy: 0.9140 - val_loss: 0.4484 - val_binary_accuracy: 0.8074
# Epoch 22/40
# 80/80 [==============================] - 9s 116ms/step - loss: 0.1982 - binary_accuracy: 0.9326 - val_loss: 0.4649 - val_binary_accuracy: 0.8111
# Epoch 23/40
# 80/80 [==============================] - 10s 122ms/step - loss: 0.1704 - binary_accuracy: 0.9443 - val_loss: 0.4782 - val_binary_accuracy: 0.8127
# Epoch 24/40
# 80/80 [==============================] - 10s 122ms/step - loss: 0.1675 - binary_accuracy: 0.9367 - val_loss: 0.4700 - val_binary_accuracy: 0.8127
# Epoch 25/40
# 80/80 [==============================] - 10s 122ms/step - loss: 0.1912 - binary_accuracy: 0.9238 - val_loss: 0.7842 - val_binary_accuracy: 0.6735
# Epoch 26/40
# 80/80 [==============================] - 10s 122ms/step - loss: 0.2086 - binary_accuracy: 0.9099 - val_loss: 0.5388 - val_binary_accuracy: 0.7794
# Epoch 27/40
# 80/80 [==============================] - 9s 119ms/step - loss: 0.1754 - binary_accuracy: 0.9322 - val_loss: 0.4834 - val_binary_accuracy: 0.8157
# Epoch 28/40
# 80/80 [==============================] - 9s 113ms/step - loss: 0.1334 - binary_accuracy: 0.9515 - val_loss: 0.5361 - val_binary_accuracy: 0.8101
# Epoch 29/40
# 80/80 [==============================] - 9s 113ms/step - loss: 0.1209 - binary_accuracy: 0.9582 - val_loss: 0.5435 - val_binary_accuracy: 0.8056
# Epoch 30/40
# 80/80 [==============================] - 9s 113ms/step - loss: 0.1342 - binary_accuracy: 0.9482 - val_loss: 0.6277 - val_binary_accuracy: 0.7981
# Epoch 31/40
# 80/80 [==============================] - 9s 115ms/step - loss: 0.1607 - binary_accuracy: 0.9359 - val_loss: 0.5178 - val_binary_accuracy: 0.8171
# Epoch 32/40
# 80/80 [==============================] - 10s 123ms/step - loss: 0.0951 - binary_accuracy: 0.9676 - val_loss: 0.6003 - val_binary_accuracy: 0.8216
# Epoch 33/40
# 80/80 [==============================] - 10s 122ms/step - loss: 0.0770 - binary_accuracy: 0.9758 - val_loss: 0.7345 - val_binary_accuracy: 0.8046
# Epoch 34/40
# 80/80 [==============================] - 10s 122ms/step - loss: 0.0758 - binary_accuracy: 0.9730 - val_loss: 0.7524 - val_binary_accuracy: 0.8044
# Epoch 35/40
# 80/80 [==============================] - 10s 122ms/step - loss: 0.0839 - binary_accuracy: 0.9701 - val_loss: 0.8203 - val_binary_accuracy: 0.7892
# Epoch 36/40
# 80/80 [==============================] - 9s 117ms/step - loss: 0.1197 - binary_accuracy: 0.9482 - val_loss: 0.9425 - val_binary_accuracy: 0.7672
# Epoch 37/40
# 80/80 [==============================] - 10s 119ms/step - loss: 0.1124 - binary_accuracy: 0.9566 - val_loss: 1.3238 - val_binary_accuracy: 0.7270
# Epoch 38/40
# 80/80 [==============================] - 10s 122ms/step - loss: 0.1153 - binary_accuracy: 0.9521 - val_loss: 0.7391 - val_binary_accuracy: 0.7998
# Epoch 39/40
# 80/80 [==============================] - 10s 122ms/step - loss: 0.0797 - binary_accuracy: 0.9701 - val_loss: 0.6478 - val_binary_accuracy: 0.8196
# Epoch 40/40
# 80/80 [==============================] - 10s 122ms/step - loss: 0.0680 - binary_accuracy: 0.9758 - val_loss: 0.6541 - val_binary_accuracy: 0.8165

# %%
import pandas as pd

history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['loss', 'val_loss']].plot()
history_frame.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot();
